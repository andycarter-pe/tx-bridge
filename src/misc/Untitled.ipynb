# %%
import rioxarray
import rasterio
import geopandas as gpd

# %matplotlib inline

# %%
cog_url = r"C:\test\n27w97_cog2.tif"

# %%
with rasterio.open(cog_url) as src:
    oviews = src.overviews(1)
    print(oviews)
    oview = oviews[-1]
# Out:
# [2, 4, 8, 16, 32, 64]

# %%
xds = rioxarray.open_rasterio(cog_url,masked=True,)

# %%
clipped = rioxarray.open_rasterio(cog_url,masked=True,).rio.clip(geometries, from_disk=True)

# %%
xds
# Out:
# <xarray.DataArray (band: 1, y: 32400, x: 32400)>
# [1049760000 values with dtype=float32]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -97.0 -97.0 -97.0 -97.0 ... -96.0 -96.0 -96.0 -96.0
#   * y            (y) float64 28.0 28.0 28.0 28.0 28.0 ... 27.0 27.0 27.0 27.0
#     spatial_ref  int32 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

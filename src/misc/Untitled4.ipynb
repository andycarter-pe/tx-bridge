# %%
import osmnx as ox

# %%
str_texas_osm = r'D:\osm_download\texas-latest.osm.bz2'

# %%
# %%time
ox.config(log_console=True)
G = ox.graph_from_xml(str_texas_osm, custom_filter='["railway"~"tram|rail"]')

# %%
import osmnx as ox
G = ox.plot_graph(ox.graph_from_place('Dallas, Texas, USA'))

# %%
# %%time
G_rail = ox.plot_graph(ox.graph_from_place('Texas, USA',
                retain_all=False, truncate_by_edge=False, simplify=False,
                custom_filter='["railway"~"tram|rail"]'))
# Out:
# CPU times: total: 7min 36s
# Wall time: 7min 39s

# %%
G_rail
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)
